# %%
import tweepy
import pandas as pd
import json

# %%
def download_twitter(searchQuery, fName, maxTweets = float('inf'), tweetsPerQry = 100):
    """
    download tweets with twitter API and store it in a txt file.
    :param searchQuery:  this is what we're searching for.
           "Bitcoin - #Bitcoin" means filtering out #Bitcoin
    :param maxTweets: Some arbitrary large number
    :param tweetsPerQry: how many tweets to get per page, 100 is the max the API permits
    :param fName: We'll store the tweets in a text file.
    :return: None
    """

    # If results from a specific ID onwards are reqd, set since_id to that ID.
    # else default to no lower limit, go as far back as API allows
    # Twitter return tweets from the most recent one, sinceId means stopping Id, max_id means start Id.
    sinceId = None

    # If results only below a specific ID are, set max_id to that ID.
    # else default to no upper limit, start from the most recent tweet matching the search query.
    max_id = -1

    tweetCount = 0
    print("Downloading max {0} tweets".format(maxTweets))
    with open(fName, 'w') as f:
        while tweetCount < maxTweets:
            try:
                if (max_id <= 0):
                    if (not sinceId):
                        new_tweets = api.search(q=searchQuery, count=tweetsPerQry,tweet_mode='extended',lang = 'en')
                    else:
                        new_tweets = api.search(q=searchQuery, count=tweetsPerQry,tweet_mode='extended',lang = 'en',
                                                since_id=sinceId)
                else:
                    if (not sinceId):
                        new_tweets = api.search(q=searchQuery, count=tweetsPerQry, tweet_mode='extended',lang = 'en',
                                                max_id=str(max_id - 1))
                    else:
                        new_tweets = api.search(q=searchQuery, count=tweetsPerQry, tweet_mode='extended',lang = 'en',
                                                max_id=str(max_id - 1),
                                                since_id=sinceId)
                if not new_tweets:
                    print("No more tweets found")
                    break
                for tweet in new_tweets:
                    f.write(json.dumps(tweet._json) +
                            '\n')  #transform from dict to json
                tweetCount += len(new_tweets)
                print("Downloaded {0} tweets".format(tweetCount))
                max_id = new_tweets[-1].id
            except tweepy.TweepError as e:
                # Just exit if any error
                print("some error : " + str(e))
                break

    print ("Downloaded {0} tweets, Saved to {1}".format(tweetCount, fName))

# %%
def get_full_text(data):
    try:
        text = data['retweeted_status']['full_text']  #get full text for retweets
    except:
        text = data['full_text']
    return text

# %%
consumer_key = 'XaYjNh6s2sG5udPG6cEQVMp53'
consumer_secret = 'ghO9RHMHVqVdjYRsqwwyIoHJOCWDJrF3XNUnOtVAdZFpEIwzlG'

auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

download_twitter(searchQuery='#BTC', fName='tweets_BTC.txt')
# Out:
# Downloading max inf tweets
# Downloaded 98 tweets
# Downloaded 198 tweets
# Downloaded 288 tweets
# Downloaded 380 tweets
# Downloaded 477 tweets
# Downloaded 563 tweets
# Downloaded 650 tweets
# Downloaded 742 tweets
# Downloaded 824 tweets
# Downloaded 909 tweets
# Downloaded 997 tweets
# Downloaded 1089 tweets
# Downloaded 1171 tweets
# Downloaded 1253 tweets
# Downloaded 1338 tweets
# Downloaded 1417 tweets
# Downloaded 1493 tweets
# Downloaded 1573 tweets
# Downloaded 1649 tweets
# Downloaded 1719 tweets
# Downloaded 1779 tweets
# Downloaded 1833 tweets
# Downloaded 1914 tweets
# Downloaded 1987 tweets
# Downloaded 2062 tweets
# Downloaded 2122 tweets
# Downloaded 2213 tweets
# Downloaded 2306 tweets
# Downloaded 2402 tweets
# Downloaded 2497 tweets
# Downloaded 2586 tweets
# Downloaded 2686 tweets
# Downloaded 2773 tweets
# Downloaded 2868 tweets
# Downloaded 2968 tweets
# Downloaded 3059 tweets
# Downloaded 3159 tweets
# Downloaded 3259 tweets
# Downloaded 3347 tweets
# Downloaded 3442 tweets
# Downloaded 3542 tweets
# Downloaded 3637 tweets
# Downloaded 3737 tweets
# Downloaded 3825 tweets
# Downloaded 3919 tweets
# Downloaded 4016 tweets
# Downloaded 4104 tweets
# Downloaded 4204 tweets
# Downloaded 4294 tweets
# Downloaded 4384 tweets
# Downloaded 4478 tweets
# Downloaded 4567 tweets
# Downloaded 4662 tweets
# Downloaded 4761 tweets
# Downloaded 4861 tweets
# Downloaded 4892 tweets
# Downloaded 4898 tweets
# Downloaded 4899 tweets
# Downloaded 4908 tweets
# Downloaded 4953 tweets
# Downloaded 5038 tweets
# Downloaded 5138 tweets
# Downloaded 5236 tweets
# Downloaded 5329 tweets
# Downloaded 5426 tweets
# Downloaded 5519 tweets
# Downloaded 5615 tweets
# Downloaded 5712 tweets
# Downloaded 5805 tweets
# Downloaded 5905 tweets
# Downloaded 5994 tweets
# Downloaded 6081 tweets
# Downloaded 6169 tweets
# Downloaded 6264 tweets
# Downloaded 6339 tweets
# Downloaded 6433 tweets
# Downloaded 6523 tweets
# Downloaded 6623 tweets
# Downloaded 6716 tweets
# Downloaded 6806 tweets
# Downloaded 6893 tweets
# Downloaded 6984 tweets
# Downloaded 7073 tweets
# Downloaded 7173 tweets
# Downloaded 7273 tweets
# Downloaded 7373 tweets
# Downloaded 7456 tweets
# Downloaded 7552 tweets
# Downloaded 7652 tweets
# Downloaded 7752 tweets
# Downloaded 7852 tweets
# Downloaded 7949 tweets
# Downloaded 8049 tweets
# Downloaded 8148 tweets
# Downloaded 8239 tweets
# Downloaded 8325 tweets
# Downloaded 8419 tweets
# Downloaded 8515 tweets
# Downloaded 8610 tweets
# Downloaded 8706 tweets
# Downloaded 8804 tweets
# Downloaded 8895 tweets
# Downloaded 8983 tweets
# Downloaded 9055 tweets
# Downloaded 9148 tweets
# Downloaded 9231 tweets
# Downloaded 9327 tweets
# Downloaded 9424 tweets
# Downloaded 9517 tweets
# Downloaded 9605 tweets
# Downloaded 9695 tweets
# Downloaded 9781 tweets
# Downloaded 9874 tweets
# Downloaded 9974 tweets
# Downloaded 10062 tweets
# Downloaded 10151 tweets
# Downloaded 10251 tweets
# Downloaded 10343 tweets
# Downloaded 10424 tweets
# Downloaded 10505 tweets
# Downloaded 10601 tweets
# Downloaded 10701 tweets
# Downloaded 10791 tweets
# Downloaded 10891 tweets
# Downloaded 10987 tweets
# Downloaded 11074 tweets
# Downloaded 11174 tweets
# Downloaded 11274 tweets
# Downloaded 11367 tweets
# Downloaded 11451 tweets
# Downloaded 11518 tweets
# Downloaded 11577 tweets
# Downloaded 11635 tweets
# Downloaded 11712 tweets
# Downloaded 11782 tweets
# Downloaded 11848 tweets
# Downloaded 11911 tweets
# Downloaded 11981 tweets
# Downloaded 12052 tweets
# Downloaded 12128 tweets
# Downloaded 12219 tweets
# Downloaded 12312 tweets
# Downloaded 12401 tweets
# Downloaded 12492 tweets
# Downloaded 12581 tweets
# Downloaded 12673 tweets
# Downloaded 12755 tweets
# Downloaded 12843 tweets
# Downloaded 12931 tweets
# Downloaded 13025 tweets
# Downloaded 13117 tweets
# Downloaded 13196 tweets
# Downloaded 13275 tweets
# Downloaded 13326 tweets
# Downloaded 13392 tweets
# Downloaded 13467 tweets
# Downloaded 13524 tweets
# Downloaded 13594 tweets
# Downloaded 13678 tweets
# Downloaded 13758 tweets
# Downloaded 13843 tweets
# Downloaded 13934 tweets
# Downloaded 14025 tweets
# Downloaded 14101 tweets
# Downloaded 14187 tweets
# Downloaded 14277 tweets
# Downloaded 14371 tweets
# Downloaded 14457 tweets
# Downloaded 14538 tweets
# Downloaded 14625 tweets
# Downloaded 14702 tweets
# Downloaded 14788 tweets
# Downloaded 14863 tweets
# Downloaded 14945 tweets
# Downloaded 15029 tweets
# Downloaded 15107 tweets
# Downloaded 15192 tweets
# Downloaded 15287 tweets
# Downloaded 15384 tweets
# Downloaded 15476 tweets
# Downloaded 15565 tweets
# Downloaded 15659 tweets
# Downloaded 15759 tweets
# Downloaded 15857 tweets
# Downloaded 15947 tweets
# Downloaded 16046 tweets
# Downloaded 16146 tweets
# Downloaded 16246 tweets
# Downloaded 16328 tweets
# Downloaded 16406 tweets
# Downloaded 16475 tweets
# Downloaded 16530 tweets
# Downloaded 16603 tweets
# Downloaded 16666 tweets
# Downloaded 16739 tweets
# Downloaded 16807 tweets
# Downloaded 16875 tweets
# Downloaded 16950 tweets

# %%
 #Data Cleaning

all = pd.read_csv('tweets_BTC.txt',sep='\n',header = None)

all['data'] = all.apply(lambda x: json.loads(x[0]), axis=1)  # transform str to dict
all['id'] = all['data'].apply(lambda x: x['id_str'])  #string format
all['text'] = all['data'].apply(get_full_text)
all['date'] = all['data'].apply(lambda x: x['created_at'])
all['favorite_count'] = all['data'].apply(lambda x: x['favorite_count'])
all['in_reply_to_status_id'] = all['data'].apply(lambda x: x['in_reply_to_status_id_str']) #contain retweet with comment and reply, string format
all['screen_name'] = all['data'].apply(lambda x: x['user']['screen_name'])
all['followers_count'] = all['data'].apply(lambda x: x['user']['followers_count'])
all = all.drop(columns = [0,'data'])
all.to_csv('tweets_BTC.csv',encoding = 'utf-8-sig',index = False)
